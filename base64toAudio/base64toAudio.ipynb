# %% [markdown]
# ## Convert base64 string to Audio

# %%
import base64

# %%
data = "..."

# %%
audio_data = base64.b64decode(data)

# %%
with open("audio_file.mp3", 'wb') as audio:
    audio.write(audio_data)

# %% [markdown]
# ## Read audio buffer from file and convert it into audio

# %%
with open("./base64.txt", "r") as base_data:
    audio_data = base64.b64decode(data)
    
    with open("c_audio.mp3", "wb") as f:
        f.write(audio_data)
